# %% [markdown]
# # Uniswap V4 Market Intel Analysis
#
# Analyze historical market intelligence snapshots.

# %%
import sys
import os
sys.path.append('..')

from lib.uv4_experiments import UV4ExperimentStore
from lib.market_intel import MarketIntelligence
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
store = UV4ExperimentStore()
df = store.to_dataframe()
if not df.empty:
    print(df.head())
    print(df['regime'].value_counts())
