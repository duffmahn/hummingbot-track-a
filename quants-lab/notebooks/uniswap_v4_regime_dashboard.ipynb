# %% [markdown]
# # Uniswap V4 Regime Dashboard
#
# Real-time view of market conditions and strategy recommendations.

# %%
import sys
sys.path.append('..')

from lib.market_intel import MarketIntelligence

# %%
intel = MarketIntelligence()
pair = "WETH-USDC"
pool = "0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640"

regime = intel.get_market_regime(pair, pool)
print(f"Current Regime: {regime['regime']}")
print(f"Details: {regime}")
